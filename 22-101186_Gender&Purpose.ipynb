# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('Life Purpose and Gender.csv')

# %%
sns.histplot(
             x="Gender",
             hue="Purpose",
             data=df,
             shrink=0.7,
             palette=sns.color_palette(['red', '#072756'])
)
# Out:
# <Axes: xlabel='Gender', ylabel='Count'>
